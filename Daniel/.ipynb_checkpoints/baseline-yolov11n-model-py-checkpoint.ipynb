# %%
# ============================================================
# 0) Install ultralytics if not 
# ============================================================
# !pip -q install -U ultralytics

from pathlib import Path
import os, random
import numpy as np
import pandas as pd
import cv2
from tqdm import tqdm

from ultralytics import YOLO
# Out:
#   error: subprocess-exited-with-error
#
#   × installing build dependencies for opencv-python did not run successfully.
#   │ exit code: 1
#   ╰─> [47 lines of output]
#       Ignoring numpy: markers 'python_version < "3.9"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.13"' don't match your environment
#       Ignoring setuptools: markers 'python_version >= "3.12"' don't match your environment
#       Collecting numpy==2.0.2
#         Using cached numpy-2.0.2.tar.gz (18.9 MB)
#         Installing build dependencies: started
#         Installing build dependencies: finished with status 'done'
#         Getting requirements to build wheel: started
#         Getting requirements to build wheel: finished with status 'done'
#         Installing backend dependencies: started
#         Installing backend dependencies: finished with status 'done'
#         Preparing metadata (pyproject.toml): started
#         Preparing metadata (pyproject.toml): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × Preparing metadata (pyproject.toml) did not run successfully.
#         │ exit code: 1
#         ╰─> [19 lines of output]
#             + /opt/conda/envs/torch/bin/python3.10 /tmp/pip-install-_fgbzu2h/numpy_e2a9c12a8293456f8adb2ffea203bcc3/vendored-meson/meson/meson.py setup /tmp/pip-install-_fgbzu2h/numpy_e2a9c12a8293456f8adb2ffea203bcc3 /tmp/pip-install-_fgbzu2h/numpy_e2a9c12a8293456f8adb2ffea203bcc3/.mesonpy-sq_1n7bl -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=/tmp/pip-install-_fgbzu2h/numpy_e2a9c12a8293456f8adb2ffea203bcc3/.mesonpy-sq_1n7bl/meson-python-native-file.ini
#             The Meson build system
#             Version: 1.4.99
#             Source dir: /tmp/pip-install-_fgbzu2h/numpy_e2a9c12a8293456f8adb2ffea203bcc3
#             Build dir: /tmp/pip-install-_fgbzu2h/numpy_e2a9c12a8293456f8adb2ffea203bcc3/.mesonpy-sq_1n7bl
#             Build type: native build
#             Project name: NumPy
#             Project version: 2.0.2
#             C compiler for the host machine: cc (gcc 7.5.0 "cc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0")
#             C linker for the host machine: cc ld.bfd 2.30
#             C++ compiler for the host machine: c++ (gcc 7.5.0 "c++ (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0")
#             C++ linker for the host machine: c++ ld.bfd 2.30
#             Cython compiler for the host machine: cython (cython 3.2.4)
#             Host machine cpu family: ppc64
#             Host machine cpu: ppc64le
#
#             ../meson.build:28:4: ERROR: Problem encountered: NumPy requires GCC >= 8.4
#
#             A full log can be found at /tmp/pip-install-_fgbzu2h/numpy_e2a9c12a8293456f8adb2ffea203bcc3/.mesonpy-sq_1n7bl/meson-logs/meson-log.txt
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: metadata-generation-failed
#
#       × Encountered error while generating package metadata.
#       ╰─> numpy
#
#       note: This is an issue with the package mentioned above, not pip.
#       hint: See above for details.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed to build 'opencv-python' when installing build dependencies for opencv-python
# ^C
# Traceback (most recent call last):
#   File "/opt/conda/envs/torch/bin/pip", line 10, in <module>
#     sys.exit(main())
#   File "/opt/conda/envs/torch/lib/python3.10/site-packages/pip/_internal/cli/main.py", line 85, in main
#     return command.main(cmd_args)
#   File "/opt/conda/envs/torch/lib/python3.10/site-packages/pip/_internal/cli/base_command.py", line 158, in main
#     with self.main_context():
#   File "/opt/conda/envs/torch/lib/python3.10/contextlib.py", line 142, in __exit__
#     next(self.gen)
#   File "/opt/conda/envs/torch/lib/python3.10/site-packages/pip/_internal/cli/command_context.py", line 20, in main_context
#     with self._main_context:
#   File "/opt/conda/envs/torch/lib/python3.10/contextlib.py", line 576, in __exit__
#     raise exc_details[1]
#   File "/opt/conda/envs/torch/lib/python3.10/contextlib.py", line 153, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "/opt/conda/envs/torch/lib/python3.10/site-packages/pip/_internal/utils/temp_dir.py", line 79, in tempdir_registry
#     yield _tempdir_registry
#   File "/opt/conda/envs/torch/lib/python3.10/contextlib.py", line 561, in __exit__
#     if cb(*exc_details):
#   File "/opt/conda/envs/torch/lib/python3.10/contextlib.py", line 142, in __exit__
#     next(self.gen)
#   File "/opt/conda/envs/torch/lib/python3.10/site-packages/pip/_internal/utils/temp_dir.py", line 40, in global_tempdir_manager
#     with ExitStack() as stack:
#   File "/opt/conda/envs/torch/lib/python3.10/contextlib.py", line 576, in __exit__
#     raise exc_details[1]
#   File "/opt/conda/envs/torch/lib/python3.10/contextlib.py", line 561, in __exit__
#     if cb(*exc_details):
#   File "/opt/conda/envs/torch/lib/python3.10/site-packages/pip/_internal/utils/temp_dir.py", line 167, in __exit__
#     self.cleanup()
#   File "/opt/conda/envs/torch/lib/python3.10/site-packages/pip/_internal/utils/temp_dir.py", line 210, in cleanup
#     rmtree(self._path, ignore_errors=False)
#   File "/opt/conda/envs/torch/lib/python3.10/site-packages/pip/_internal/utils/retry.py", line 37, in retry_wrapped
#     return func(*args, **kwargs)
#   File "/opt/conda/envs/torch/lib/python3.10/site-packages/pip/_internal/utils/misc.py", line 130, in rmtree
#     shutil.rmtree(dir, onerror=handler)  # type: ignore
#   File "/opt/conda/envs/torch/lib/python3.10/shutil.py", line 724, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/opt/conda/envs/torch/lib/python3.10/shutil.py", line 657, in _rmtree_safe_fd
#     _rmtree_safe_fd(dirfd, fullname, onerror)
#   File "/opt/conda/envs/torch/lib/python3.10/shutil.py", line 657, in _rmtree_safe_fd
#     _rmtree_safe_fd(dirfd, fullname, onerror)
#   File "/opt/conda/envs/torch/lib/python3.10/shutil.py", line 657, in _rmtree_safe_fd
#     _rmtree_safe_fd(dirfd, fullname, onerror)
#   [Previous line repeated 1 more time]
#   File "/opt/conda/envs/torch/lib/python3.10/shutil.py", line 656, in _rmtree_safe_fd
#     if os.path.samestat(orig_st, os.fstat(dirfd)):
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 13
#      10 import cv2
#      11 from tqdm import tqdm
# ---> 13 from ultralytics import YOLO
#
# ModuleNotFoundError: No module named 'ultralytics'

# %%
#  Model train on train set 1
DATA_DIR = Path("/kaggle/input/multi-view-pig-posture-recognition/multiview_pig_posture_recognition")
OUT_DIR  = Path("/kaggle/working")

train_csv = DATA_DIR / "train1.csv"
test_csv  = DATA_DIR / "test.csv"
train_img_dir = DATA_DIR / "train1_images"
test_img_dir  = DATA_DIR / "test_images"

print(train_csv.exists(), test_csv.exists(), train_img_dir.exists(), test_img_dir.exists())

# ============================================================
# 1) Helpers: bbox parsing + crop
# ============================================================
def parse_bbox_string(bbox_str: str):
    s = str(bbox_str).strip()
    if s.startswith("[") and s.endswith("]"):
        s = s[1:-1].strip()
    s = s.replace(",", " ")
    parts = [p for p in s.split() if p]
    if len(parts) != 4:
        raise ValueError(f"Bad bbox: {bbox_str}")
    x, y, w, h = map(float, parts)
    return x, y, w, h

def safe_crop(img, x, y, w, h, pad=10):
    H, W = img.shape[:2]
    x1 = int(max(0, np.floor(x) - pad))
    y1 = int(max(0, np.floor(y) - pad))
    x2 = int(min(W, np.ceil(x + w) + pad))
    y2 = int(min(H, np.ceil(y + h) + pad))
    if x2 <= x1 or y2 <= y1:
        return np.zeros((32,32,3), dtype=img.dtype)
    return img[y1:y2, x1:x2]

# ============================================================
# 2) Build classification crop dataset from train.csv
# ============================================================
df = pd.read_csv(train_csv)
assert "class_id" in df.columns and "bbox" in df.columns and "image_id" in df.columns and "row_id" in df.columns

# split train/val by row (simple baseline)
seed = 42
rng = np.random.default_rng(seed)
perm = rng.permutation(len(df))
val_ratio = 0.2
n_val = int(round(val_ratio * len(df)))
val_idx = set(perm[:n_val].tolist())

cls_root = OUT_DIR / "cls_data"
train_root = cls_root / "train"
val_root   = cls_root / "val"
train_root.mkdir(parents=True, exist_ok=True)
val_root.mkdir(parents=True, exist_ok=True)

# Create class folders
classes = sorted(df["class_id"].unique().tolist())
for c in classes:
    (train_root / str(c)).mkdir(parents=True, exist_ok=True)
    (val_root / str(c)).mkdir(parents=True, exist_ok=True)

pad = 10
img_size = 224

# Cache images to speed up (optional)
img_cache = {}

def read_rgb(path: Path):
    im = cv2.imread(str(path))
    if im is None:
        raise RuntimeError(f"Cannot read {path}")
    return cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

print("Building crop dataset...")
for i, r in tqdm(df.iterrows(), total=len(df)):
    img_path = train_img_dir / r["image_id"]
    key = str(img_path)
    if key not in img_cache:
        img_cache[key] = read_rgb(img_path)
    img = img_cache[key]

    x, y, w, h = parse_bbox_string(r["bbox"])
    crop = safe_crop(img, x, y, w, h, pad=pad)
    crop = cv2.resize(crop, (img_size, img_size), interpolation=cv2.INTER_AREA)

    split_root = val_root if i in val_idx else train_root
    out_path = split_root / str(int(r["class_id"])) / f"{r['row_id']}.jpg"

    # Ultralytics expects standard images; save RGB as BGR
    cv2.imwrite(str(out_path), cv2.cvtColor(crop, cv2.COLOR_RGB2BGR))

print("Crop dataset ready:", cls_root)

# ============================================================
# 3) Train Ultralytics classification model
# ============================================================
# Common options: yolo11n-cls.pt, yolo11s-cls.pt (names can vary by ultralytics version)
# Here we use yolo11n-cls.pt as baseline.
weights = "yolo11n-cls.pt"
try:
    model = YOLO(weights)
except Exception as e:
    print("Failed to load", weights, "-> fallback to yolov8n-cls.pt")
    weights = "yolov8n-cls.pt"
    model = YOLO(weights)

results = model.train(
    data=str(cls_root),   # folder with train/ and val/
    epochs=40,
    imgsz=img_size,
    batch=64,
    device=0,
    workers=2,
    seed=seed,
    
    fliplr=0.0,
    flipud=0.0,
)

best_pt = model.trainer.best
print("Best model:", best_pt)

# ============================================================
# 4) Predict on test.csv crops and build submission.csv
# ============================================================
df_test = pd.read_csv(test_csv)

# Load model from best checkpoint
model = YOLO(best_pt)

test_cache = {}

def get_img(path: Path):
    key = str(path)
    if key not in test_cache:
        test_cache[key] = read_rgb(path)
    return test_cache[key]

pred_rows = []

print("Predicting test crops...")
for _, r in tqdm(df_test.iterrows(), total=len(df_test)):
    img = get_img(test_img_dir / r["image_id"])
    x, y, w, h = parse_bbox_string(r["bbox"])
    crop = safe_crop(img, x, y, w, h, pad=pad)
    crop = cv2.resize(crop, (img_size, img_size), interpolation=cv2.INTER_AREA)

    # Ultralytics predict accepts numpy image (BGR) or path; we pass BGR
    crop_bgr = cv2.cvtColor(crop, cv2.COLOR_RGB2BGR)
    out = model.predict(source=crop_bgr, verbose=False)

    # top1 class index
    top1 = int(out[0].probs.top1)
    pred_rows.append((r["row_id"], top1))

sub_path = OUT_DIR / "submission.csv"
pd.DataFrame(pred_rows, columns=["row_id", "class_id"]).to_csv(sub_path, index=False)
print("Wrote:", sub_path)
print(pd.read_csv(sub_path).head())

# ============================================================
# 5) Save important outputs permanently for future
# ============================================================

OUTPUT_DIR = Path("/kaggle/working/output_train1")
OUTPUT_DIR.mkdir(exist_ok=True)

# Save crops for debugging
if (OUT_DIR / "cls_data").exists():
    # !cp -r /kaggle/working/cls_data /kaggle/working/output/

# Save best model checkpoint
best_model_out = OUTPUT_DIR / "best.pt"
# !cp "{best_pt}" "{best_model_out}"

# Save submission file
submission_out = OUTPUT_DIR / "submission.csv"
# !cp /kaggle/working/submission.csv  "{submission_out}"

print("Saved outputs to:", OUTPUT_DIR)
print("Files:", os.listdir(OUTPUT_DIR))
# Out:
# True True True True
# Building crop dataset...
# 100%|██████████| 22934/22934 [01:44<00:00, 218.79it/s]
# Crop dataset ready: /kaggle/working/cls_data
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n-cls.pt to 'yolo11n-cls.pt': 100% ━━━━━━━━━━━━ 5.5MB 64.0MB/s 0.1s
# Ultralytics 8.3.252 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=64, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/cls_data, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=40, erasing=0.4, exist_ok=False, fliplr=0.0, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/classify/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# train: /kaggle/working/cls_data/train... found 18347 images in 5 classes ✅
# val: /kaggle/working/cls_data/val... found 4587 images in 5 classes ✅
# test: None...
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  10                  -1  1    336645  ultralytics.nn.modules.head.Classify         [256, 5]
# YOLO11n-cls summary: 86 layers, 1,537,509 parameters, 1,537,509 gradients, 3.3 GFLOPs
# Transferred 234/236 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 61.2MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 344.2±197.9 MB/s, size: 11.7 KB)
# train: Scanning /kaggle/working/cls_data/train... 18347 images, 0 corrupt: 100% ━━━━━━━━━━━━ 18347/18347 2.8Kit/s 6.6s
# train: New cache created: /kaggle/working/cls_data/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 215.2±70.3 MB/s, size: 11.8 KB)
# val: Scanning /kaggle/working/cls_data/val... 4587 images, 0 corrupt: 100% ━━━━━━━━━━━━ 4587/4587 3.0Kit/s 1.5s
# val: New cache created: /kaggle/working/cls_data/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/classify/train
# Starting training for 40 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 14.7MB/s 0.1s
#        1/40      1.04G      1.022         43        224: 100% ━━━━━━━━━━━━ 287/287 4.4it/s 1:05
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 8.0it/s 4.5s
#                    all      0.673          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/40      1.04G     0.6115         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.1it/s 5.1s
#                    all       0.84          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/40      1.05G     0.5548         43        224: 100% ━━━━━━━━━━━━ 287/287 4.8it/s 59.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.2it/s 5.0s
#                    all      0.711          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/40      1.05G     0.5148         43        224: 100% ━━━━━━━━━━━━ 287/287 4.9it/s 58.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.0it/s 5.1s
#                    all      0.769          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/40      1.06G     0.4176         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.1it/s 5.0s
#                    all       0.85          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/40      1.06G     0.3682         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.5it/s 4.8s
#                    all      0.839          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/40      1.07G     0.3295         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.0it/s 5.2s
#                    all       0.87          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/40      1.08G     0.3038         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 6.8it/s 5.3s
#                    all      0.907          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/40      1.08G     0.2826         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.1it/s 5.1s
#                    all      0.864          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/40      1.09G     0.2609         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.2it/s 5.0s
#                    all      0.905          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/40      1.09G     0.2527         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.1it/s 5.1s
#                    all      0.914          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/40       1.1G     0.2378         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.4it/s 4.9s
#                    all      0.923          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/40      1.11G     0.2267         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.4it/s 4.9s
#                    all      0.844          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/40      1.11G      0.213         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.4it/s 4.9s
#                    all      0.908          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/40      1.12G     0.2076         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.0it/s 5.1s
#                    all      0.922          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/40      1.12G     0.1955         43        224: 100% ━━━━━━━━━━━━ 287/287 4.9it/s 59.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.2it/s 5.0s
#                    all      0.931          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/40      1.13G     0.1798         43        224: 100% ━━━━━━━━━━━━ 287/287 4.9it/s 58.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.6it/s 4.8s
#                    all      0.929          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/40      1.13G      0.175         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.2it/s 5.0s
#                    all      0.928          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/40      1.14G     0.1676         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.2it/s 5.0s
#                    all      0.931          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/40      1.15G     0.1662         43        224: 100% ━━━━━━━━━━━━ 287/287 4.9it/s 58.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.1it/s 5.1s
#                    all      0.933          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/40      1.15G     0.1516         43        224: 100% ━━━━━━━━━━━━ 287/287 4.9it/s 58.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.3it/s 4.9s
#                    all      0.934          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/40      1.16G      0.139         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.2it/s 5.0s
#                    all      0.937          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/40      1.16G     0.1403         43        224: 100% ━━━━━━━━━━━━ 287/287 4.9it/s 58.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.0it/s 5.1s
#                    all      0.937          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/40      1.17G     0.1367         43        224: 100% ━━━━━━━━━━━━ 287/287 4.9it/s 58.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 6.9it/s 5.2s
#                    all      0.943          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       25/40      1.17G     0.1274         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.0it/s 5.1s
#                    all      0.939          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       26/40      1.18G      0.119         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.3it/s 5.0s
#                    all      0.945          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       27/40      1.19G     0.1133         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 6.9it/s 5.2s
#                    all      0.937          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       28/40      1.19G     0.1005         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.1it/s 5.0s
#                    all      0.945          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       29/40       1.2G      0.101         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.4it/s 4.8s
#                    all      0.946          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       30/40       1.2G    0.09589         43        224: 100% ━━━━━━━━━━━━ 287/287 4.9it/s 58.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 6.8it/s 5.3s
#                    all      0.945          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       31/40      1.21G    0.08825         43        224: 100% ━━━━━━━━━━━━ 287/287 4.8it/s 59.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.3it/s 4.9s
#                    all      0.945          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       32/40      1.21G    0.07464         43        224: 100% ━━━━━━━━━━━━ 287/287 4.9it/s 58.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.5it/s 4.8s
#                    all      0.943          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       33/40      1.22G    0.07778         43        224: 100% ━━━━━━━━━━━━ 287/287 4.8it/s 59.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.3it/s 4.9s
#                    all      0.944          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       34/40      1.23G    0.07518         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.7it/s 4.7s
#                    all      0.944          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       35/40      1.23G    0.06924         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.7it/s 4.7s
#                    all      0.944          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       36/40      1.24G     0.0663         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.6it/s 4.7s
#                    all      0.945          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       37/40      1.24G    0.05705         43        224: 100% ━━━━━━━━━━━━ 287/287 5.1it/s 56.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.4it/s 4.9s
#                    all      0.946          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       38/40      1.25G    0.05926         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.6it/s 4.7s
#                    all      0.945          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       39/40      1.26G    0.05314         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.5it/s 4.8s
#                    all      0.945          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       40/40      1.26G    0.04887         43        224: 100% ━━━━━━━━━━━━ 287/287 5.0it/s 57.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.7it/s 4.7s
#                    all      0.944          1
#
# 40 epochs completed in 0.702 hours.
# Optimizer stripped from /kaggle/working/runs/classify/train/weights/last.pt, 3.2MB
# Optimizer stripped from /kaggle/working/runs/classify/train/weights/best.pt, 3.2MB
#
# Validating /kaggle/working/runs/classify/train/weights/best.pt...
# Ultralytics 8.3.252 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLO11n-cls summary (fused): 47 layers, 1,532,429 parameters, 0 gradients, 3.2 GFLOPs
# train: /kaggle/working/cls_data/train... found 18347 images in 5 classes ✅
# val: /kaggle/working/cls_data/val... found 4587 images in 5 classes ✅
# test: None...
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 36/36 7.8it/s 4.6s
#                    all      0.946          1
# Speed: 0.1ms preprocess, 0.2ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /kaggle/working/runs/classify/train
# Best model: /kaggle/working/runs/classify/train/weights/best.pt
# Predicting test crops...
# 100%|██████████| 11708/11708 [01:44<00:00, 112.38it/s]
# Wrote: /kaggle/working/submission.csv
#                                     row_id  class_id
# 0  test_pen1_tur_cam1_20250920_174649_0000         3
# 1  test_pen1_tur_cam1_20250920_174649_0001         4
# 2  test_pen1_tur_cam1_20250920_174649_0002         4
# 3  test_pen1_tur_cam1_20250920_174649_0003         4
# 4  test_pen1_tur_cam1_20250920_174649_0004         0
# Saved outputs to: /kaggle/working/output_train1
# Files: ['best.pt', 'submission.csv']

# %%
# Model train on train set 2
DATA_DIR = Path("/kaggle/input/multi-view-pig-posture-recognition/multiview_pig_posture_recognition")
OUT_DIR  = Path("/kaggle/working")

train_csv = DATA_DIR / "train2.csv"
test_csv  = DATA_DIR / "test.csv"
train_img_dir = DATA_DIR / "train2_images"
test_img_dir  = DATA_DIR / "test_images"

print(train_csv.exists(), test_csv.exists(), train_img_dir.exists(), test_img_dir.exists())

# ============================================================
# 1) Helpers: bbox parsing + crop
# ============================================================
def parse_bbox_string(bbox_str: str):
    s = str(bbox_str).strip()
    if s.startswith("[") and s.endswith("]"):
        s = s[1:-1].strip()
    s = s.replace(",", " ")
    parts = [p for p in s.split() if p]
    if len(parts) != 4:
        raise ValueError(f"Bad bbox: {bbox_str}")
    x, y, w, h = map(float, parts)
    return x, y, w, h

def safe_crop(img, x, y, w, h, pad=10):
    H, W = img.shape[:2]
    x1 = int(max(0, np.floor(x) - pad))
    y1 = int(max(0, np.floor(y) - pad))
    x2 = int(min(W, np.ceil(x + w) + pad))
    y2 = int(min(H, np.ceil(y + h) + pad))
    if x2 <= x1 or y2 <= y1:
        return np.zeros((32,32,3), dtype=img.dtype)
    return img[y1:y2, x1:x2]

# ============================================================
# 2) Build classification crop dataset from train.csv
# ============================================================
df = pd.read_csv(train_csv)
assert "class_id" in df.columns and "bbox" in df.columns and "image_id" in df.columns and "row_id" in df.columns

# split train/val by row (simple baseline)
seed = 42
rng = np.random.default_rng(seed)
perm = rng.permutation(len(df))
val_ratio = 0.2
n_val = int(round(val_ratio * len(df)))
val_idx = set(perm[:n_val].tolist())

cls_root = OUT_DIR / "cls_data"
train_root = cls_root / "train"
val_root   = cls_root / "val"
train_root.mkdir(parents=True, exist_ok=True)
val_root.mkdir(parents=True, exist_ok=True)

# Create class folders
classes = sorted(df["class_id"].unique().tolist())
for c in classes:
    (train_root / str(c)).mkdir(parents=True, exist_ok=True)
    (val_root / str(c)).mkdir(parents=True, exist_ok=True)

pad = 10
img_size = 224

# Cache images to speed up (optional)
img_cache = {}

def read_rgb(path: Path):
    im = cv2.imread(str(path))
    if im is None:
        raise RuntimeError(f"Cannot read {path}")
    return cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

print("Building crop dataset...")
for i, r in tqdm(df.iterrows(), total=len(df)):
    img_path = train_img_dir / r["image_id"]
    key = str(img_path)
    if key not in img_cache:
        img_cache[key] = read_rgb(img_path)
    img = img_cache[key]

    x, y, w, h = parse_bbox_string(r["bbox"])
    crop = safe_crop(img, x, y, w, h, pad=pad)
    crop = cv2.resize(crop, (img_size, img_size), interpolation=cv2.INTER_AREA)

    split_root = val_root if i in val_idx else train_root
    out_path = split_root / str(int(r["class_id"])) / f"{r['row_id']}.jpg"

    # Ultralytics expects standard images; save RGB as BGR
    cv2.imwrite(str(out_path), cv2.cvtColor(crop, cv2.COLOR_RGB2BGR))

print("Crop dataset ready:", cls_root)

# ============================================================
# 3) Train Ultralytics classification model
# ============================================================
# Common options: yolo11n-cls.pt, yolo11s-cls.pt (names can vary by ultralytics version)
# Here we use yolo11n-cls.pt as baseline.
weights = "yolo11n-cls.pt"
try:
    model = YOLO(weights)
except Exception as e:
    print("Failed to load", weights, "-> fallback to yolov8n-cls.pt")
    weights = "yolov8n-cls.pt"
    model = YOLO(weights)

results = model.train(
    data=str(cls_root),   # folder with train/ and val/
    epochs=40,
    imgsz=img_size,
    batch=64,
    device=0,
    workers=2,
    seed=seed,
    
    fliplr=0.0,
    flipud=0.0,
)

best_pt = model.trainer.best
print("Best model:", best_pt)

# ============================================================
# 4) Predict on test.csv crops and build submission.csv
# ============================================================
df_test = pd.read_csv(test_csv)

# Load model from best checkpoint
model = YOLO(best_pt)

test_cache = {}

def get_img(path: Path):
    key = str(path)
    if key not in test_cache:
        test_cache[key] = read_rgb(path)
    return test_cache[key]

pred_rows = []

print("Predicting test crops...")
for _, r in tqdm(df_test.iterrows(), total=len(df_test)):
    img = get_img(test_img_dir / r["image_id"])
    x, y, w, h = parse_bbox_string(r["bbox"])
    crop = safe_crop(img, x, y, w, h, pad=pad)
    crop = cv2.resize(crop, (img_size, img_size), interpolation=cv2.INTER_AREA)

    # Ultralytics predict accepts numpy image (BGR) or path; we pass BGR
    crop_bgr = cv2.cvtColor(crop, cv2.COLOR_RGB2BGR)
    out = model.predict(source=crop_bgr, verbose=False)

    # top1 class index
    top1 = int(out[0].probs.top1)
    pred_rows.append((r["row_id"], top1))

sub_path = OUT_DIR / "submission.csv"
pd.DataFrame(pred_rows, columns=["row_id", "class_id"]).to_csv(sub_path, index=False)
print("Wrote:", sub_path)
print(pd.read_csv(sub_path).head())

# ============================================================
# 5) Save important outputs permanently for future
# ============================================================

OUTPUT_DIR = Path("/kaggle/working/output_train2")
OUTPUT_DIR.mkdir(exist_ok=True)

# Save crops for debugging
if (OUT_DIR / "cls_data").exists():
    # !cp -r /kaggle/working/cls_data /kaggle/working/output/

# Save best model checkpoint
best_model_out = OUTPUT_DIR / "best.pt"
# !cp "{best_pt}" "{best_model_out}"

# Save submission file
submission_out = OUTPUT_DIR / "submission.csv"
# !cp /kaggle/working/submission.csv  "{submission_out}"

print("Saved outputs to:", OUTPUT_DIR)
print("Files:", os.listdir(OUTPUT_DIR))
# Out:
# True True True True
# Building crop dataset...
#  53%|█████▎    | 12492/23450 [01:09<12:43, 14.35it/s]

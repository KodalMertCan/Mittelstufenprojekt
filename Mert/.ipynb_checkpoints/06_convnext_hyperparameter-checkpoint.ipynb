# %% [markdown]
# # Baseline
# Ansatz:
# - Übersicht der Multi-view Pig Posture Recognition Challenge
# - Datenanalyse und -vorverarbeitung
# - Baseline Modellierung für zukunfitge Optimierungen

# %%
# Cell 1: Imports
import os
import json
import copy
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import torch
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from torch.utils.data import DataLoader, Dataset, WeightedRandomSampler
from torchvision import models, transforms
from torchvision.transforms import functional as TF
from tqdm import tqdm
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import StratifiedGroupKFold, train_test_split
import warnings
warnings.filterwarnings("ignore")

device = torch.device("cuda:3" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# <jemalloc>: Unsupported system page size
# Using device: cuda:3

# %% [markdown]
# ## Datenanalyse

# %%
# Cell 2: Load data
data_dir = "/datasets/multi-view-pig-posture-recognition/"
train2_df = pd.read_csv(os.path.join(data_dir, "train2.csv"))
dir_train2 = os.path.join(data_dir, "train2_images")

test_df = pd.read_csv(os.path.join(data_dir, "test.csv"))
dir_test = os.path.join(data_dir, "test_images")

def parse_bbox_safe(x):
    if isinstance(x, str):
        return [float(i) for i in x.replace("[", "").replace("]", "").split(",")]
    return x

train2_df["bbox"] = train2_df["bbox"].apply(parse_bbox_safe)
test_df["bbox"] = test_df["bbox"].apply(lambda x: json.loads(x) if isinstance(x, str) else x)

# Extract camera_id for group-aware splitting
train2_df["camera_id"] = train2_df["image_id"].apply(lambda x: x.split("_")[0])

print(f"Train2: {len(train2_df)} samples")
print(f"Test:   {len(test_df)} samples")
print(f"\nKlassenverteilung:")
print(train2_df["class_id"].value_counts().sort_index())
print(f"\nKameras: {train2_df['camera_id'].nunique()}")
# Out:
# Train2: 23450 samples
# Test:   11708 samples
#
# Klassenverteilung:
# class_id
# 0    3083
# 1    3435
# 2     695
# 3    9928
# 4    6309
# Name: count, dtype: int64
#
# Kameras: 2

# %%
# Cell 3: EDA - Class distribution
class_counts = train2_df["class_id"].value_counts().sort_index()
plt.figure(figsize=(10, 5))
sns.barplot(x=class_counts.index, y=class_counts.values)
plt.title("Klassenverteilung Train2")
plt.xlabel("Class ID")
plt.ylabel("Anzahl")
plt.show()

# Camera x Class distribution
camera_class_counts = (
    train2_df.groupby(["camera_id", "class_id"]).size().unstack(fill_value=0)
)
plt.figure(figsize=(12, 6))
camera_class_counts.plot(kind="bar", stacked=True, ax=plt.gca())
plt.title("Verteilung der Klassen pro Kamera")
plt.xlabel("Kamera ID")
plt.ylabel("Anzahl der Bilder")
plt.legend(title="Class ID")
plt.tight_layout()
plt.show()

# %%
# Cell 4: Dataset with bbox padding for context
class PigPostureDataset(Dataset):
    def __init__(self, df, img_dir, transform=None, bbox_pad_ratio=0.15):
        self.df = df.reset_index(drop=True)
        self.img_dir = img_dir
        self.transform = transform
        self.bbox_pad_ratio = bbox_pad_ratio

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        img_path = os.path.join(self.img_dir, row["image_id"])
        image = Image.open(img_path).convert("RGB")
        label = row["class_id"]

        bbox = row["bbox"]
        if isinstance(bbox, str):
            bbox = [float(x) for x in bbox.replace("[", "").replace("]", "").split(",")]
        x, y, w, h = bbox
        img_w, img_h = image.size

        # Add padding around bbox for context
        pad_w = w * self.bbox_pad_ratio
        pad_h = h * self.bbox_pad_ratio
        x1 = max(0, int(x - pad_w))
        y1 = max(0, int(y - pad_h))
        x2 = min(img_w, int(x + w + pad_w))
        y2 = min(img_h, int(y + h + pad_h))
        image = image.crop((x1, y1, x2, y2))

        if self.transform:
            image = self.transform(image)

        return image, label

# %%
# Cell 5: Augmentations — strong train, clean val
IMG_SIZE_PHASE1 = 224
IMG_SIZE_PHASE2 = 384

def get_train_transform(img_size):
    return transforms.Compose([
        transforms.Resize((img_size + 32, img_size + 32)),
        transforms.RandomCrop((img_size, img_size)),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomVerticalFlip(p=0.3),
        transforms.RandomRotation(20),
        transforms.RandomAffine(degrees=0, translate=(0.1, 0.1), scale=(0.9, 1.1), shear=10),
        transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.2, hue=0.05),
        transforms.RandomGrayscale(p=0.05),
        transforms.GaussianBlur(kernel_size=3, sigma=(0.1, 2.0)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
        transforms.RandomErasing(p=0.3, scale=(0.02, 0.15)),
    ])

def get_val_transform(img_size):
    return transforms.Compose([
        transforms.Resize((img_size, img_size)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

# %%
# Cell 6: MixUp & CutMix helpers
def mixup_data(x, y, alpha=0.4):
    lam = np.random.beta(alpha, alpha) if alpha > 0 else 1.0
    batch_size = x.size(0)
    index = torch.randperm(batch_size).to(x.device)
    mixed_x = lam * x + (1 - lam) * x[index]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam

def cutmix_data(x, y, alpha=1.0):
    lam = np.random.beta(alpha, alpha)
    batch_size = x.size(0)
    index = torch.randperm(batch_size).to(x.device)
    _, _, H, W = x.shape

    cut_rat = np.sqrt(1.0 - lam)
    cut_w = int(W * cut_rat)
    cut_h = int(H * cut_rat)
    cx = np.random.randint(W)
    cy = np.random.randint(H)

    x1 = np.clip(cx - cut_w // 2, 0, W)
    y1 = np.clip(cy - cut_h // 2, 0, H)
    x2 = np.clip(cx + cut_w // 2, 0, W)
    y2 = np.clip(cy + cut_h // 2, 0, H)

    x[:, :, y1:y2, x1:x2] = x[index, :, y1:y2, x1:x2]
    lam = 1 - ((x2 - x1) * (y2 - y1) / (W * H))
    y_a, y_b = y, y[index]
    return x, y_a, y_b, lam

def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %%
# Cell 7: Cosine Annealing with Warmup scheduler
class CosineWarmupScheduler(torch.optim.lr_scheduler._LRScheduler):
    def __init__(self, optimizer, warmup_epochs, max_epochs, min_lr=1e-7, last_epoch=-1):
        self.warmup_epochs = warmup_epochs
        self.max_epochs = max_epochs
        self.min_lr = min_lr
        super().__init__(optimizer, last_epoch)

    def get_lr(self):
        if self.last_epoch < self.warmup_epochs:
            alpha = self.last_epoch / max(1, self.warmup_epochs)
            return [base_lr * alpha for base_lr in self.base_lrs]
        else:
            progress = (self.last_epoch - self.warmup_epochs) / max(1, self.max_epochs - self.warmup_epochs)
            cosine_decay = 0.5 * (1 + math.cos(math.pi * progress))
            return [self.min_lr + (base_lr - self.min_lr) * cosine_decay for base_lr in self.base_lrs]

# %% [markdown]
# # Model

# %%
# Cell 8: EMA (Exponential Moving Average)
class ModelEMA:
    def __init__(self, model, decay=0.999):
        self.ema_model = copy.deepcopy(model)
        self.ema_model.eval()
        self.decay = decay
        for p in self.ema_model.parameters():
            p.requires_grad_(False)

    def update(self, model):
        with torch.no_grad():
            for ema_p, model_p in zip(self.ema_model.parameters(), model.parameters()):
                ema_p.data.mul_(self.decay).add_(model_p.data, alpha=1 - self.decay)

    def state_dict(self):
        return self.ema_model.state_dict()

    def load_state_dict(self, state_dict):
        self.ema_model.load_state_dict(state_dict)

# %%
# Cell 9: Model — ConvNeXt-Base with stronger head (FIXED)
class PigPostureModel(nn.Module):
    def __init__(self, num_classes=5, backbone_name="convnext_base"):
        super().__init__()
        self.backbone_name = backbone_name

        if backbone_name == "convnext_base":
            self.backbone = models.convnext_base(weights=models.ConvNeXt_Base_Weights.DEFAULT)
            in_features = self.backbone.classifier[2].in_features
            # Replace the entire classifier with Identity to get raw features
            self.backbone.classifier = nn.Identity()
        elif backbone_name == "efficientnet_v2_m":
            self.backbone = models.efficientnet_v2_m(weights=models.EfficientNet_V2_M_Weights.DEFAULT)
            in_features = self.backbone.classifier[1].in_features
            self.backbone.classifier = nn.Identity()
        else:
            raise ValueError(f"Unknown backbone: {backbone_name}")

        print(f"Backbone feature dim: {in_features}")

        self.head = nn.Sequential(
            nn.LayerNorm(in_features),
            nn.Dropout(0.4),
            nn.Linear(in_features, 512),
            nn.GELU(),
            nn.Dropout(0.2),
            nn.Linear(512, num_classes),
        )

        # Freeze backbone initially
        for param in self.backbone.parameters():
            param.requires_grad = False

    def unfreeze_backbone(self, fraction=1.0):
        params = list(self.backbone.parameters())
        num_unfreeze = int(len(params) * fraction)
        for param in params[-num_unfreeze:]:
            param.requires_grad = True
        trainable = sum(p.requires_grad for p in self.backbone.parameters())
        print(f"Unfroze {trainable}/{len(params)} backbone parameters")

    def forward(self, x):
        features = self.backbone(x)
        # Debug: check feature shape
        if features.dim() == 4:  # ConvNeXt may output (B, C, H, W) without avgpool
            features = features.mean([-2, -1])  # Global Average Pooling
        return self.head(features)

# Quick sanity check
BACKBONE = "convnext_base"
model = PigPostureModel(num_classes=5, backbone_name=BACKBONE)
model.to(device)

# Verify with dummy input
dummy = torch.randn(2, 3, 224, 224).to(device)
with torch.no_grad():
    out = model(dummy)
print(f"Model: {BACKBONE}")
print(f"Output shape: {out.shape}")  # Should be (2, 5)
print(f"Trainable params: {sum(p.numel() for p in model.parameters() if p.requires_grad):,}")
# Out:
# Backbone feature dim: 1024
# Model: convnext_base
# Output shape: torch.Size([2, 5])
# Trainable params: 529,413

# %%
# Cell 10: Stratified GroupKFold split (by camera)
sgkf = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=42)
groups = train2_df["camera_id"].values
labels = train2_df["class_id"].values

# Use first fold
train_idx, val_idx = next(iter(sgkf.split(train2_df, labels, groups)))
train_split_df = train2_df.iloc[train_idx]
val_split_df = train2_df.iloc[val_idx]

print(f"Train: {len(train_split_df)} | Val: {len(val_split_df)}")
print(f"Train cameras: {train_split_df['camera_id'].unique()}")
print(f"Val cameras:   {val_split_df['camera_id'].unique()}")
print(f"Camera overlap: {set(train_split_df['camera_id']) & set(val_split_df['camera_id'])}")
# Out:
# Train: 10604 | Val: 12846
# Train cameras: ['pen1']
# Val cameras:   ['pen2']
# Camera overlap: set()

# %%
# Cell 11: Weighted sampler for class imbalance
def get_weighted_sampler(df):
    class_counts = df["class_id"].value_counts().sort_index().values
    class_weights = 1.0 / class_counts
    sample_weights = [class_weights[label] for label in df["class_id"].values]
    sampler = WeightedRandomSampler(sample_weights, num_samples=len(sample_weights), replacement=True)
    return sampler

train_dataset = PigPostureDataset(train_split_df, dir_train2, transform=get_train_transform(IMG_SIZE_PHASE1))
val_dataset = PigPostureDataset(val_split_df, dir_train2, transform=get_val_transform(IMG_SIZE_PHASE1))

sampler = get_weighted_sampler(train_split_df)
train_loader = DataLoader(train_dataset, batch_size=32, sampler=sampler, num_workers=4, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# %%
# Cell 12: Training loop with MixUp/CutMix, gradient accumulation, EMA
from torch.cuda.amp import GradScaler, autocast

def train_model_advanced(
    model, train_loader, val_loader, criterion, optimizer, scheduler,
    num_epochs=20, save_name="best_model.pth",
    use_mixup=True, use_cutmix=True, accumulation_steps=2, use_ema=True
):
    model.to(device)
    ema = ModelEMA(model, decay=0.999) if use_ema else None
    scaler = GradScaler()  # Fixed: use torch.cuda.amp.GradScaler

    train_loss_history, val_loss_history, val_acc_history = [], [], []
    best_val_acc = 0.0

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        optimizer.zero_grad()

        for step, (images, labels) in enumerate(tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs} [Train]")):
            images, labels = images.to(device), labels.to(device)

            r = np.random.random()
            if use_mixup and r < 0.3:
                images, y_a, y_b, lam = mixup_data(images, labels)
                use_mix = True
            elif use_cutmix and r < 0.6:
                images, y_a, y_b, lam = cutmix_data(images, labels)
                use_mix = True
            else:
                use_mix = False

            with autocast():  # Fixed: use torch.cuda.amp.autocast
                outputs = model(images)
                if use_mix:
                    loss = mixup_criterion(criterion, outputs, y_a, y_b, lam)
                else:
                    loss = criterion(outputs, labels)
                loss = loss / accumulation_steps

            scaler.scale(loss).backward()

            if (step + 1) % accumulation_steps == 0:
                scaler.step(optimizer)
                scaler.update()
                optimizer.zero_grad()
                if ema:
                    ema.update(model)

            running_loss += loss.item() * accumulation_steps * images.size(0)

        epoch_train_loss = running_loss / len(train_loader.dataset)
        train_loss_history.append(epoch_train_loss)

        eval_model = ema.ema_model if ema else model
        eval_model.to(device)
        eval_model.eval()
        val_loss, correct, total = 0.0, 0, 0

        with torch.no_grad():
            for images, labels in tqdm(val_loader, desc=f"Epoch {epoch+1}/{num_epochs} [Val]"):
                images, labels = images.to(device), labels.to(device)
                with autocast():  # Fixed
                    outputs = eval_model(images)
                    loss = criterion(outputs, labels)
                val_loss += loss.item() * images.size(0)
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        epoch_val_loss = val_loss / len(val_loader.dataset)
        epoch_val_acc = correct / total
        val_loss_history.append(epoch_val_loss)
        val_acc_history.append(epoch_val_acc)

        if scheduler:
            scheduler.step()

        current_lr = optimizer.param_groups[0]["lr"]
        print(f"Epoch {epoch+1}/{num_epochs} | "
              f"Train Loss: {epoch_train_loss:.4f} | "
              f"Val Loss: {epoch_val_loss:.4f} | "
              f"Val Acc: {epoch_val_acc:.4f} | "
              f"LR: {current_lr:.2e}")

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            state = ema.state_dict() if ema else model.state_dict()
            torch.save(state, save_name)
            print(f"  -> Best model saved! (Val Acc: {best_val_acc:.4f})")

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    axes[0].plot(range(1, num_epochs + 1), train_loss_history, marker="o", label="Train Loss")
    axes[0].plot(range(1, num_epochs + 1), val_loss_history, marker="s", label="Val Loss")
    axes[0].set_title("Loss")
    axes[0].set_xlabel("Epoch")
    axes[0].legend()
    axes[0].grid()

    axes[1].plot(range(1, num_epochs + 1), val_acc_history, marker="o", color="green")
    axes[1].set_title("Validation Accuracy")
    axes[1].set_xlabel("Epoch")
    axes[1].grid()
    plt.tight_layout()
    plt.show()
    print(f"\nBest Validation Accuracy: {best_val_acc:.4f}")
    return best_val_acc

# %%
# Cell 13: Phase 1 — Train head only (frozen backbone)
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
optimizer = torch.optim.AdamW(model.head.parameters(), lr=1e-3, weight_decay=1e-2)
scheduler = CosineWarmupScheduler(optimizer, warmup_epochs=2, max_epochs=12)

print("=== Phase 1: Train Head Only ===")
train_model_advanced(
    model, train_loader, val_loader, criterion, optimizer, scheduler,
    num_epochs=15, save_name="best_T2_phase1.pth",
    use_mixup=True, use_cutmix=True, accumulation_steps=2
)
# Out:
# === Phase 1: Train Head Only ===
# ...
# Epoch 1/15 [Val]: 100%|██████████| 402/402 [01:24<00:00,  4.76it/s]
# Epoch 1/15 | Train Loss: 1.0703 | Val Loss: 1.2015 | Val Acc: 0.5567 | LR: 5.00e-04
#   -> Best model saved! (Val Acc: 0.5567)
# ...
# Epoch 2/15 [Val]: 100%|██████████| 402/402 [01:24<00:00,  4.76it/s]
# Epoch 2/15 | Train Loss: 1.0582 | Val Loss: 1.2002 | Val Acc: 0.5585 | LR: 1.00e-03
#   -> Best model saved! (Val Acc: 0.5585)
# ...
# Epoch 3/15 [Val]: 100%|██████████| 402/402 [01:21<00:00,  4.95it/s]
# Epoch 3/15 | Train Loss: 1.0627 | Val Loss: 1.2042 | Val Acc: 0.5550 | LR: 9.76e-04
# ...
# Epoch 4/15 [Val]: 100%|██████████| 402/402 [02:19<00:00,  2.88it/s]
# Epoch 4/15 | Train Loss: 1.0472 | Val Loss: 1.2006 | Val Acc: 0.5530 | LR: 9.05e-04
# ...
# Epoch 5/15 [Val]: 100%|██████████| 402/402 [02:17<00:00,  2.93it/s]
# Epoch 5/15 | Train Loss: 1.0282 | Val Loss: 1.1984 | Val Acc: 0.5513 | LR: 7.94e-04
# ...
# Epoch 6/15 [Val]: 100%|██████████| 402/402 [02:28<00:00,  2.71it/s]
# ...

# %%
# Cell 14: Phase 2 — Unfreeze last 30% backbone, lower LR (FIXED)
model.load_state_dict(torch.load("best_T2_phase1.pth", map_location=device))
model.unfreeze_backbone(fraction=0.3)

optimizer_ft = torch.optim.AdamW([
    {"params": [p for p in model.backbone.parameters() if p.requires_grad], "lr": 5e-6},
    {"params": model.head.parameters(), "lr": 1e-4},
], weight_decay=1e-2)
scheduler_ft = CosineWarmupScheduler(optimizer_ft, warmup_epochs=2, max_epochs=15)

print("=== Phase 2: Fine-Tune Backbone (30%) ===")
train_model_advanced(
    model, train_loader, val_loader, criterion, optimizer_ft, scheduler_ft,
    num_epochs=15, save_name="best_T2_phase2.pth",
    use_mixup=False, use_cutmix=False, accumulation_steps=2
)
# Out:
# Unfroze 102/340 backbone parameters
# === Phase 2: Fine-Tune Backbone (30%) ===
# ...
# Epoch 1/15 [Val]: 100%|██████████| 402/402 [02:03<00:00,  3.26it/s]
# Epoch 1/15 | Train Loss: 0.8665 | Val Loss: 1.2002 | Val Acc: 0.5585 | LR: 2.50e-06
#   -> Best model saved! (Val Acc: 0.5585)
# ...
# Epoch 2/15 [Val]: 100%|██████████| 402/402 [02:18<00:00,  2.91it/s]
# Epoch 2/15 | Train Loss: 0.8567 | Val Loss: 1.2037 | Val Acc: 0.5567 | LR: 5.00e-06
# ...
# Epoch 3/15 [Val]:  89%|████████▉ | 358/402 [02:05<00:15,  2.85it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 12
#       9 scheduler_ft = CosineWarmupScheduler(optimizer_ft, warmup_epochs=2, max_epochs=15)
#      11 print("=== Phase 2: Fine-Tune Backbone (30%) ===")
# ---> 12 train_model_advanced(
#      13     model, train_loader, val_loader, criterion, optimizer_ft, scheduler_ft,
# ...

# %%
# Cell 15: Phase 3 — Progressive resizing to 384, full unfreeze
model.load_state_dict(torch.load("best_T2_phase2.pth", map_location=device))
model.unfreeze_backbone(fraction=1.0)

# Rebuild dataloaders with larger images
train_dataset_384 = PigPostureDataset(train_split_df, dir_train2, transform=get_train_transform(IMG_SIZE_PHASE2))
val_dataset_384 = PigPostureDataset(val_split_df, dir_train2, transform=get_val_transform(IMG_SIZE_PHASE2))

train_loader_384 = DataLoader(train_dataset_384, batch_size=16, sampler=get_weighted_sampler(train_split_df),
                               num_workers=4, pin_memory=True)
val_loader_384 = DataLoader(val_dataset_384, batch_size=16, shuffle=False, num_workers=4, pin_memory=True)

optimizer_384 = torch.optim.AdamW(model.parameters(), lr=5e-6, weight_decay=1e-2)
scheduler_384 = CosineWarmupScheduler(optimizer_384, warmup_epochs=1, max_epochs=10)

print("=== Phase 3: Full Fine-Tune @ 384px ===")
train_model_advanced(
    model, train_loader_384, val_loader_384, criterion, optimizer_384, scheduler_384,
    num_epochs=5, save_name="best_T2_final.pth",
    use_mixup=True, use_cutmix=True, accumulation_steps=4
)

# %%
# Cell 16: Evaluation with confusion matrix and classification report
model.load_state_dict(torch.load("best_T2_final.pth", map_location=device))
model.to(device)
model.eval()

all_labels, all_preds = [], []
with torch.no_grad():
    for images, labels in tqdm(val_loader_384, desc="Evaluating"):
        images, labels = images.to(device), labels.to(device)
        with torch.amp.autocast("cuda"):
            outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(predicted.cpu().numpy())

accuracy = np.mean(np.array(all_labels) == np.array(all_preds))
print(f"\nFinal Val Accuracy: {accuracy:.4f}")
print(f"\n{classification_report(all_labels, all_preds, digits=4)}")

cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=range(5), yticklabels=range(5))
plt.title(f"Confusion Matrix (Acc: {accuracy:.4f})")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# %%
# Cell 17: Test-Time Augmentation (TTA) Inference
def get_tta_transforms(img_size=384):
    """Return list of transform variants for TTA."""
    base_norm = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    return [
        # Original
        transforms.Compose([transforms.Resize((img_size, img_size)), transforms.ToTensor(), base_norm]),
        # HFlip
        transforms.Compose([transforms.Resize((img_size, img_size)), transforms.RandomHorizontalFlip(p=1.0),
                             transforms.ToTensor(), base_norm]),
        # VFlip
        transforms.Compose([transforms.Resize((img_size, img_size)), transforms.RandomVerticalFlip(p=1.0),
                             transforms.ToTensor(), base_norm]),
        # Slight rotation via crop
        transforms.Compose([transforms.Resize((img_size + 32, img_size + 32)),
                             transforms.CenterCrop(img_size), transforms.ToTensor(), base_norm]),
        # HFlip + crop
        transforms.Compose([transforms.Resize((img_size + 32, img_size + 32)),
                             transforms.CenterCrop(img_size), transforms.RandomHorizontalFlip(p=1.0),
                             transforms.ToTensor(), base_norm]),
    ]

model.load_state_dict(torch.load("best_T2_final.pth", map_location=device))
model.to(device)
model.eval()

tta_transforms = get_tta_transforms(IMG_SIZE_PHASE2)
row_ids = []
predictions = []
all_logits = []

with torch.no_grad():
    for _, row in tqdm(test_df.iterrows(), total=len(test_df), desc="TTA Inference"):
        row_id = row["row_id"]
        image_id = row["image_id"]
        img_path = os.path.join(dir_test, image_id)
        image = Image.open(img_path).convert("RGB")

        bbox = row["bbox"]
        if isinstance(bbox, str):
            bbox = json.loads(bbox)
        x, y, w, h = bbox
        img_w, img_h = image.size

        # Crop with padding
        pad_w = w * 0.15
        pad_h = h * 0.15
        x1 = max(0, int(x - pad_w))
        y1 = max(0, int(y - pad_h))
        x2 = min(img_w, int(x + w + pad_w))
        y2 = min(img_h, int(y + h + pad_h))
        cropped = image.crop((x1, y1, x2, y2))

        # TTA: average logits across augmentations
        logits_sum = None
        for t in tta_transforms:
            img_tensor = t(cropped).unsqueeze(0).to(device)
            with autocast():
                logits = model(img_tensor)
            if logits_sum is None:
                logits_sum = logits
            else:
                logits_sum += logits

        avg_logits = logits_sum / len(tta_transforms)
        _, pred = torch.max(avg_logits, 1)

        row_ids.append(row_id)
        predictions.append(pred.item())
        all_logits.append(avg_logits.cpu().numpy().flatten())

submission = pd.DataFrame({"row_id": row_ids, "class_id": predictions})
submission.to_csv("T2_convnext_tta.csv", index=False)

# Also save raw logits for ensembling later
logits_df = pd.DataFrame(all_logits, columns=[f"logit_{i}" for i in range(5)])
logits_df["row_id"] = row_ids
logits_df.to_csv("T2_convnext_logits.csv", index=False)

print("\n✅ Saved: T2_convnext_tta.csv")
print(f"\nKlassenverteilung:")
print(submission["class_id"].value_counts().sort_index().to_string())
print(submission.head())

# %%
# SCHRITT 1: Diagnostik — Was passiert wirklich? (< 2 min)
import numpy as np
from collections import Counter
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

model.load_state_dict(torch.load("best_T2_phase1.pth", map_location=device))
model.eval()

all_preds = []
all_labels = []

with torch.no_grad():
    for images, labels in val_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

all_preds = np.array(all_preds)
all_labels = np.array(all_labels)

# Klassenverteilung
print("=== Klassenverteilung (Val) ===")
label_counts = Counter(all_labels)
pred_counts = Counter(all_preds)
for k in sorted(label_counts.keys()):
    print(f"  Klasse {k}: {label_counts[k]} echte | {pred_counts.get(k, 0)} vorhergesagt")

# Classification Report
print("\n=== Classification Report ===")
print(classification_report(all_labels, all_preds, digits=3))

# Confusion Matrix
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()

# Prüfe ob Modell nur 1-2 Klassen vorhersagt
print(f"\n=== Vorhersage-Verteilung ===")
print(f"Unique predictions: {np.unique(all_preds)}")
print(f"Prediction counts: {Counter(all_preds)}")
# Out:
# === Klassenverteilung (Val) ===
#   Klasse 0: 1233 echte | 2555 vorhergesagt
#   Klasse 1: 1880 echte | 898 vorhergesagt
#   Klasse 2: 512 echte | 1047 vorhergesagt
#   Klasse 3: 6053 echte | 6400 vorhergesagt
#   Klasse 4: 3168 echte | 1946 vorhergesagt
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0      0.170     0.353     0.230      1233
#            1      0.313     0.149     0.202      1880
#            2      0.245     0.502     0.330       512
#            3      0.799     0.845     0.821      6053
#            4      0.559     0.343     0.425      3168
#
#     accuracy                          0.558     12846
#    macro avg      0.417     0.438     0.402     12846
# weighted avg      0.586     0.558     0.556     12846
# === Vorhersage-Verteilung ===
# Unique predictions: [0 1 2 3 4]
# Prediction counts: Counter({3: 6400, 0: 2555, 4: 1946, 2: 1047, 1: 898})

# %%
# Cell 50: Balanced Training Setup
from collections import Counter
from torch.utils.data import WeightedRandomSampler

# Klassenverteilung im TRAIN Set zählen
train_labels = []
for _, labels in train_loader:
    train_labels.extend(labels.numpy().tolist())

class_counts = Counter(train_labels)
num_classes = len(class_counts)
total = sum(class_counts.values())

# Class Weights berechnen
class_weights = []
for i in range(num_classes):
    w = total / (num_classes * class_counts[i])
    class_weights.append(w)
    print(f"Klasse {i}: {class_counts[i]} samples, weight={w:.3f}")

class_weights_tensor = torch.FloatTensor(class_weights).to(device)
criterion = nn.CrossEntropyLoss(weight=class_weights_tensor, label_smoothing=0.1)

# WeightedRandomSampler
sample_weights = [class_weights[label] for label in train_labels]
sampler = WeightedRandomSampler(
    weights=sample_weights,
    num_samples=len(sample_weights),
    replacement=True
)

train_loader_balanced = torch.utils.data.DataLoader(
    train_loader.dataset,
    batch_size=train_loader.batch_size,
    sampler=sampler,
    num_workers=train_loader.num_workers,
    pin_memory=True,
    drop_last=True
)

print(f"\n✅ Balanced DataLoader: {len(train_loader_balanced)} Batches")
print(f"✅ Weighted Loss: {class_weights_tensor}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 7
#       5 # Klassenverteilung im TRAIN Set zählen
#       6 train_labels = []
# ----> 7 for _, labels in train_loader:
#       8     train_labels.extend(labels.numpy().tolist())
#      10 class_counts = Counter(train_labels)
#
# File /opt/conda/envs/torch/lib/python3.10/site-packages/torch/utils/data/dataloader.py:681, in _BaseDataLoaderIter.__next__(self)
#     678 if self._sampler_iter is None:
#     679     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     680     self._reset()  # type: ignore[call-arg]
# --> 681 data = self._next_data()
#     682 self._num_yielded += 1
#     683 if self._dataset_kind == _DatasetKind.Iterable and \
#     684         self._IterableDataset_len_called is not None and \
#     685         self._num_yielded > self._IterableDataset_len_called:
#
# ...

# %%
# Cell 51: Phase 1 NEU — Balanced Training
model = PigPostureModel(num_classes=5, backbone_name="convnext_base")
model.to(device)

optimizer = torch.optim.AdamW(model.head.parameters(), lr=1e-3, weight_decay=1e-2)
scheduler = CosineWarmupScheduler(optimizer, warmup_epochs=2, max_epochs=15)

print("=== Phase 1: Train Head (BALANCED) ===")
train_model_advanced(
    model, train_loader_balanced, val_loader, criterion, optimizer, scheduler,
    num_epochs=15, save_name="best_T2_balanced_phase1.pth",
    use_mixup=False, use_cutmix=False, accumulation_steps=2
)
